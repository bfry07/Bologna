# %%
# import necessary packaages
import numpy as np
import pandas as pd
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs

# import data sets
    # base map of statistical areas
base_map_data = gpd.read_file("./Data/aree-statistiche.geojson")
    
    # population data
#population = 

    # airbnb data
airbnb = pd.read_csv("./Data/bologna-rilevazione-airbnb.csv", on_bad_lines='warn')

    # wifi data
wifi = pd.read_csv("./Data/bolognawifi-elenco-hot-spot.csv", on_bad_lines='warn')

#to view data
base_map_data
# Out:
#     codice_area_statistica                                       geo_point_2d  \
# 0                       10  {'lon': 11.256359721086515, 'lat': 44.50890866...
# 1                       29  {'lon': 11.337680323624046, 'lat': 44.50126629...
# 2                       57  {'lon': 11.358772141816008, 'lat': 44.47950537...
# 3                       58  {'lon': 11.371435156894728, 'lat': 44.48062788...
# 4                       77  {'lon': 11.3337576922741, 'lat': 44.4926477919...
# ..                     ...                                                ...
# 85                      49  {'lon': 11.369102069643551, 'lat': 44.50037967...
# 86                      46  {'lon': 11.413677041239703, 'lat': 44.50971045...
# 87                      22  {'lon': 11.361830658518647, 'lat': 44.52779328...
# 88                      60  {'lon': 11.347202228024338, 'lat': 44.49578410...
# 89                      23  {'lon': 11.331562767824904, 'lat': 44.54076442...
#
#            area_statistica  cod_quar                quartiere cod_zona  \
# 0                   RIGOSA        11    Borgo Panigale - Reno        C
# 1                MARCONI-2        13        Porto - Saragozza        M
# 2               SIEPELUNGA        15            Santo Stefano        O
# 3                  DAGNINI        15            Santo Stefano        O
# 4               MALPIGHI-2        13        Porto - Saragozza        L
# ..                     ...       ...                      ...      ...
# 85               VIA MONDO        14  San Donato - San Vitale        Q
# 86  SCALO MERCI SAN DONATO        14  San Donato - San Vitale        Q
# 87                LA DOZZA        12                   Navile        E
# 88               IRNERIO-1        15            Santo Stefano        H
# 89    LAGHETTI DEL ROSARIO        12                   Navile        I
#
#               zona                                           geometry
# 0   Borgo Panigale  POLYGON ((11.26336 44.52599, 11.26349 44.52617...
# 1          Marconi  POLYGON ((11.34230 44.49899, 11.34234 44.49906...
# 2            Murri  POLYGON ((11.36410 44.47982, 11.36374 44.48010...
# 3            Murri  POLYGON ((11.37637 44.47930, 11.37636 44.47965...
# 4         Malpighi  POLYGON ((11.32772 44.49906, 11.32757 44.49911...
# ..             ...                                                ...
# 85      San Donato  POLYGON ((11.37338 44.50173, 11.37321 44.50178...
# 86      San Donato  POLYGON ((11.43061 44.51090, 11.43062 44.51096...
# 87      Corticella  POLYGON ((11.36684 44.52840, 11.36689 44.52886...
# 88         Irnerio  POLYGON ((11.35019 44.49610, 11.35040 44.49617...
# 89            Lame  POLYGON ((11.34808 44.55213, 11.34795 44.55215...
#
# [90 rows x 8 columns]

# %%
# clean and combine the datasets

    # AIRBNB
    # extract the latitude and longitude of each airbnb
airbnb[['lat','long']] = airbnb['Coordinate'].str.split(',',expand=True)
    # turn the airbnb data into a geo data frame
airbnb_geo = gpd.GeoDataFrame(
    airbnb, geometry=gpd.points_from_xy(airbnb.long, airbnb.lat), crs="EPSG:4326"
)

    # WIFI
    # turn the wifi data into a geo data frame
wifi_geo = gpd.GeoDataFrame(
    wifi, geometry=gpd.points_from_xy(wifi.x, wifi.y), crs="EPSG:4326"
)


#to view data
wifi_geo
# Out:
#                             Hostname          x          y  \
# 0               ap-lepida-arboreto-1  11.387130  44.507970
# 1             ap-lepida-sfrancesco-1  11.334880  44.495080
# 2                  ap-lepida-unita-1  11.347190  44.511610
# 3                  ap-lepida-verdi-1  11.350524  44.496260
# 4                  ap-lepida-verdi-2  11.350856  44.496375
# ..                               ...        ...        ...
# 298                 Salone-indiano-3  11.343430  44.494610
# 299                 Salone-indiano-4  11.343430  44.494610
# 300              Sottopasso-mostra-5  11.343430  44.494610
# 301            wifi-velostazione-bar  11.345320  44.503534
# 302  wifi-velostazione-corridoionord  11.345320  44.503534
#
#         area statistica zona di prossimità  \
# 0              PILASTRO   SAN DONATO NUOVO
# 1            MALPIGHI-2           MALPIGHI
# 2    PIAZZA DELL'UNITA'          BOLOGNINA
# 3             IRNERIO-2            IRNERIO
# 4             IRNERIO-2            IRNERIO
# ..                  ...                ...
# 298           GALVANI-1            GALVANI
# 299           GALVANI-1            GALVANI
# 300           GALVANI-1            GALVANI
# 301           IRNERIO-2            IRNERIO
# 302           IRNERIO-2            IRNERIO
#
#                                geopoint Attivo                   geometry
# 0                    44.50797, 11.38713     Sì  POINT (11.38713 44.50797)
# 1                    44.49508, 11.33488     Sì  POINT (11.33488 44.49508)
# 2                    44.51161, 11.34719     Sì  POINT (11.34719 44.51161)
# 3    44.4962604407939, 11.3505238294601     Sì  POINT (11.35052 44.49626)
# 4     44.4963752332499, 11.350856423378     Sì  POINT (11.35086 44.49638)
# ..                                  ...    ...                        ...
# 298                  44.49461, 11.34343     Sì  POINT (11.34343 44.49461)
# 299                  44.49461, 11.34343     Sì  POINT (11.34343 44.49461)
# 300                  44.49461, 11.34343     Sì  POINT (11.34343 44.49461)
# 301         44.5035340096, 11.345320344     Sì  POINT (11.34532 44.50353)
# 302         44.5035340096, 11.345320344     Sì  POINT (11.34532 44.50353)
#
# [303 rows x 8 columns]

# %%
# map the data
    # display the base map information
base_map_fig = base_map_data.plot(color="darkgrey", edgecolor="lightgrey") # creates a base map of the neighborhood areas 
base_map_fig.axis('off') # removes the ugly axes
    
    # plot airbnbs
#airbnb_geo.plot(ax = base_map_fig, color = "red", markersize = 1)

    # plot wifi locations
wifi_geo.plot(ax = base_map_fig, color = "blue", markersize = 1)
# Out:
# <Axes: >
